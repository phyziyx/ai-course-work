# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('cellPhone_train.csv')
train_df.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
test_df = pd.read_csv('cellPhone_test.csv')
test_df.head(5)
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
print('test_df:')

for k in test_df:
    print(k)
    
print('\n\ntrain_df:')
    
for k in train_df:
    print(k)
# Out:
# test_df:
# id
# battery_power
# blue
# clock_speed
# dual_sim
# fc
# four_g
# int_memory
# m_dep
# mobile_wt
# n_cores
# pc
# px_height
# px_width
# ram
# sc_h
# sc_w
# talk_time
# three_g
# touch_screen
# wifi
#
#
# train_df:
# battery_power
# blue
# clock_speed
# dual_sim
# fc
# four_g
# int_memory
# m_dep
# mobile_wt
# n_cores
# pc
# px_height
# px_width
# ram
# sc_h
# sc_w
# talk_time
# three_g
# touch_screen
# wifi
# price_range

# %%
clean_train = train_df # .drop('price_range', axis = 1)

X_train = clean_train.drop('price_range', axis = 1)
y_train = clean_train['price_range']

clean_train.drop(['price_range'], axis = 1)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
clean_train.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

######################################

clean_test = test_df.drop(['id'], axis = 1)
# clean_test['price_range'] = clean_test['price_range'].


# y_test = 

######################################

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

print(f'clean_test keys: {len(clean_test.keys())}')
for k in clean_test:
    print(f'clean_test keys: {k}')

print(f'clean_train keys: {len(clean_train.keys())}')
for k in clean_train:
    print(f'clean_train keys: {k}')

clean_test = clean_test.drop('price_range', axis = 1)
clean_train = clean_train.drop('price_range', axis = 1)
new_dataframe = knn.predict(clean_test)

clean_test["price_range"]=new_dataframe

new_dataframe

clean_test.head()
# Out:
# clean_test keys: 21
# clean_test keys: battery_power
# clean_test keys: blue
# clean_test keys: clock_speed
# clean_test keys: dual_sim
# clean_test keys: fc
# clean_test keys: four_g
# clean_test keys: int_memory
# clean_test keys: m_dep
# clean_test keys: mobile_wt
# clean_test keys: n_cores
# clean_test keys: pc
# clean_test keys: px_height
# clean_test keys: px_width
# clean_test keys: ram
# clean_test keys: sc_h
# clean_test keys: sc_w
# clean_test keys: talk_time
# clean_test keys: three_g
# clean_test keys: touch_screen
# clean_test keys: wifi
# clean_test keys: price_range
# clean_train keys: 21
# clean_train keys: battery_power
# clean_train keys: blue
# clean_train keys: clock_speed
# clean_train keys: dual_sim
# clean_train keys: fc
# clean_train keys: four_g
# clean_train keys: int_memory
# clean_train keys: m_dep
# clean_train keys: mobile_wt
# clean_train keys: n_cores
# clean_train keys: pc
# clean_train keys: px_height
# clean_train keys: px_width
# ...

# %%
clean_test.to_csv('predictions.csv', ['id', 'price_range'], index = False)
# prediction = pd.DataFrame(new_dataframe, columns=['predictions']).to_csv('predictions.csv')
